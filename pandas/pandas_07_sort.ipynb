# %%
import pandas as pd

people = {
    "first": ["Corey", "Jane", "John", "Adam"],
    "last": ["Schafer", "Doe", "Doe", "Doe"],
    "email": [
        "CoreyMSchafer@gmail.com",
        "JaneDoe@gmail.com",
        "JohnDoe@gmail.com",
        "A@gmail.com",
    ],
}

# %%
df = pd.DataFrame(people)
df.head()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %% [markdown]
# # sort_values method

# %%
df.sort_values(by="last", ascending=False, inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df.sort_values(by=["last", "first"], ascending=[False, True], inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe              A@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %%
df.sort_index(inplace=True)
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com
# 3   Adam      Doe              A@gmail.com

# %%
df["last"].sort_values()  # returns a series
# Out:
# 1        Doe
# 2        Doe
# 3        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.sort_values(by=["Country", "ConvertedComp"], ascending=[True, False], inplace=True)
df[["Country", "ConvertedComp"]].head(5)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0

# %% [markdown]
# # nlargest/ nsmallest method

# %%
df["ConvertedComp"].nlargest(10)  # returns the 10 largest values
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
# to get all columns
df.nlargest(3, "ConvertedComp")
# Out:
#                                 MainBranch Hobbyist              OpenSourcer  \
# Respondent
# 25983       I am a developer by profession      Yes  Less than once per year
# 87896       I am a developer by profession      Yes  Less than once per year
# 22013       I am a developer by profession      Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 25983       OSS is, on average, of HIGHER quality than pro...
# 87896       The quality of OSS and closed source software ...
# 22013       The quality of OSS and closed source software ...
#
#                     Employment  Country Student  \
# Respondent
# 25983       Employed full-time   Canada      No
# 87896       Employed full-time  Germany      No
# 22013       Employed full-time    India      No
#
#                                              EdLevel  \
# Respondent
# 25983       Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
df.nsmallest(3, "ConvertedComp")
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 722         I am a developer by profession       No
# 28638       I am a developer by profession      Yes
# 13825       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 722         Less than once a month but more than once per ...
# 28638       Less than once a month but more than once per ...
# 13825                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 722         The quality of OSS and closed source software ...
# 28638       OSS is, on average, of HIGHER quality than pro...
# 13825       The quality of OSS and closed source software ...
#
#                                                    Employment      Country  \
# Respondent
# 722                                                       NaN  Afghanistan
# ...
